# %%
digits = [1, 1,0]
digits_rev = digits[::-1]
print(digits_rev)
# Out:
# [0, 1, 1]

# %%
sum_digit = 0

for i in range(len(digits_rev)) :
            sum_digit += digits_rev[i]*pow(2,i)

print(sum_digit)
# Out:
# 6

# %%
5//2
# Out:
# 2
